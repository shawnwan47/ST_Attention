# %%
from imp import reload
from lib import IO
from lib import Loader
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import networkx as nx

# %%
reload(Loader)
la = Loader.LALoader()
link = la.load_link()

# %%
def link_to_dist(link):
    G = nx.DiGraph()
    G.add_weighted_edges_from([(i, j, w) for (i, j), w in link.iteritems()])
    return G

G = link_to_dist(link)

# %%
G.adj
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
G[1201054][1201066]
# Out:
# {'weight': 2610.9000000000001}

# %%
dist = nx.shortest_path_length(G, weight='weight')
dist = {k: v for k, v in dist}

# %%
dist = pd.DataFrame(length)
print(dist)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
G = nx.DiGraph()
edges = [(i, j, w) for (i, j), w in link.iteritems()]
G.add_weighted_edges_from(edges)

# %%
nx.draw(G)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\networkx\drawing\layout.py in fruchterman_reingold_layout(G, k, pos, fixed, iterations, weight, scale, center, dim)
#     325         pos = _sparse_fruchterman_reingold(A, k, pos_arr, fixed,
# --> 326                                            iterations, dim)
#     327     except:
#
# C:\ProgramData\Anaconda3\lib\site-packages\networkx\drawing\layout.py in _sparse_fruchterman_reingold(A, k, pos, fixed, iterations, dim)
#     471             displacement[:, i] +=\
# --> 472                 (delta * (k * k / distance**2 - Ai * distance / k)).sum(axis=1)
#     473         # update positions
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims)
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
# ...

# %%
reload(Loader)
la = Loader.LALoader()
idx = pd.IndexSlice

# %%
dist.max()
# Out:
# 773869    2.417270e+04
# 767541    3.477050e+04
# 767542    3.612190e+04
# 717447    3.481920e+04
# 717446    3.305180e+04
# 717445    3.751520e+04
# 773062    3.670720e+04
# 767620    3.615460e+04
# 737529    4.062650e+04
# 717816    3.402360e+04
# 765604    2.544160e+04
# 767471    3.419260e+04
# 716339    3.085060e+04
# 773906    2.734150e+04
# 765273    3.864690e+04
# 716331    3.338830e+04
# 771667    3.680830e+04
# 716337    3.329770e+04
# 769953    4.238640e+04
# 769402    2.601160e+04
# 769403    2.474070e+04
# 769819    4.017130e+04
# 769405    2.393090e+04
# 716941    3.992510e+04
# 717578    2.872850e+04
# 716960    3.118870e+04
# 717804             inf
# 767572    3.495920e+04
# 767573    3.668930e+04
# 773012    4.185700e+04
#               ...
# 767554    3.548600e+04
# 773975    4.152830e+04
# 773974    3.356150e+04
# 717510    3.800530e+04
# 717513    3.962050e+04
# 717825    3.916470e+04
# 767495    3.522430e+04
# 767494    3.514230e+04
# 717821    4.079570e+04
# ...

# %%
dist
# Out:
#          773869   767541   767542   717447   717446   717445   773062  \
# from
# 773869      0.0  10597.8  11949.2  14297.6  13953.3  16879.9  16584.2
# 767541  13239.2      0.0   2504.6   8563.7   8570.7   9560.9   9590.0
# 767542  12045.9   1489.3      0.0   6971.2   6978.2   9148.0   9177.1
# 717447  14936.8   6805.8   9293.6      0.0   1745.5   6068.7   5400.9
# 717446  15543.4   6606.4   9111.0   1767.4      0.0   4463.4   3655.4
# 717445  15532.7   6595.8   9100.4    861.6   2607.1      0.0   4654.3
# 773062  19499.5   9452.8  11747.1   5264.2   6985.0   4402.6      0.0
# 767620  11919.0   5925.6   4436.3  11407.5  11414.5  13130.0  13159.1
# 737529  18466.3  29064.1  30415.5  29122.4  27355.0  31818.4  31010.4
# 717816  15884.4  26482.2  27833.6  26530.9  24763.5  29226.9  28418.9
# 765604   8761.2  19359.0  20710.4  19841.5  18074.1  22537.5  21729.5
# 767471  11670.1   8243.8   6754.5  13725.7  13732.7  15448.2  15477.3
# ...

# %%
sns.distplot(dist.values.reshape(-1))
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-146-601704a08f7e> in <module>()
# ----> 1 sns.distplot(dist.values.reshape(-1))
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     206     if hist:
#     207         if bins is None:
# --> 208             bins = min(_freedman_diaconis_bins(a), 50)
#     209         hist_kws.setdefault("alpha", 0.4)
#     210         hist_kws.setdefault("normed", norm_hist)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py in _freedman_diaconis_bins(a)
#      32         return int(np.sqrt(a.size))
#      33     else:
# ---> 34         return int(np.ceil((a.max() - a.min()) / h))
#      35
#      36
#
# OverflowError: cannot convert float infinity to integer

# %%
link.loc[idx[sorted(la.ids_int), :]]
# Out:
# ---------------------------------------------------------------------------
# UnsortedIndexError                        Traceback (most recent call last)
# <ipython-input-110-19d62f5262ba> in <module>()
# ----> 1 link.loc[idx[sorted(la.ids_int), :]]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1323             except (KeyError, IndexError):
#    1324                 pass
# -> 1325             return self._getitem_tuple(key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     834     def _getitem_tuple(self, tup):
#     835         try:
# --> 836             return self._getitem_lowerdim(tup)
#     837         except IndexingError:
#     838             pass
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
# ...

# %%
plt.show()
# Out:
# 21254.799999999999

# %%
dist_mat = dist.unstack()

# %%
dist_mat.fillna(float('inf'))
# Out:
#                  cost                                                       \
# to            715898        715915       715916       715918       715920
# from
# 715898   0.000000e+00  1.064190e+04          inf          inf          inf
# 715915            inf  0.000000e+00  3294.100000  1116.800000  4905.900000
# 715916   7.880400e+03  2.436500e+03     0.000000  3553.500000  7164.300000
# 715918            inf  6.213000e+03  5533.100000     0.000000  4008.500000
# 715920   9.624300e+03  4.180300e+03  1743.600000  5297.300000     0.000000
# 715921   9.972800e+03  4.528800e+03  2092.100000  5645.800000   348.400000
# 715922   1.033510e+04  4.891100e+03  2454.400000  6008.100000   710.700000
# 715929            inf  8.200300e+03  6174.600000  9317.300000  4430.900000
# 715930            inf  9.499500e+03  7902.800000          inf  6159.100000
# 715933            inf  1.099400e+04  9397.200000          inf  7653.500000
# ...
